# %%
from statistics import median
import math
from random import choice
import random

#Definicion de variables
cartas_truco={'1 de Espada':14,'1 de Basto':13,'7 de Espada':12,'7 de Oro':11,'3 de Espada':10,'3 de Oro':10,'3 de Copa':10,
              '3 de Basto':10,' 2 de Espada':9,'2 de Oro':9,' 2 de Copa':9,' 2 de Basto':9,'1 de Copa':8,'1 de Oro':8,
     '12 de Espada':7,'12 de Oro':7,'12 de Copa':7,'12 de Basto':7,'11 de Espada':6,'11 de Oro':6,'11 de Copa':6,
              '11 de Basto':6,'10 de Espada':5,'10 de Oro':5,'10 de Copa':5,'10 de Basto':5,'7 de Copa':4,'7 de Oro':4,
    '6 de Espada':3,'6 de Oro':3,'6 de Copa':3,'6 de Basto':3,'5 de Espada':2,'5 de Oro':2,'5 de Copa':2,'5 de Basto':2,
              '4 de Espada':1,'4 de Oro':1,'4 de Copa':1,'4 de Basto':14}

cpu_score_batalla = 0
player_score_batalla = 0

cpu_score_ronda = 0
player_score_ronda = 0

rounds_to_win = math.ceil(n_rounds/2)


#Ingresar el nombre del jugador
nombre=input("Ingrese Nombre: ")
print(nombre.upper(),"Empecemos!")


# Seleccionar el numero de rondas 
n_rounds = input("Ingrese la cantidad de rondas que quiere jugar, recuerde que las rondas deben ser numeros impares:")
n_rounds= int(n_rounds)
if n_rounds%2 == 0: 
    print("Introduce un numero impar por favor")
else:
    print("Vamos a jugar:", n_rounds, "rondas")
    
    
def Jugador(cartas_truco):
    keys = random.sample(list(cartas_truco.items()), 3)
    return(keys)


def Computadora(cartas_truco):
    keys = random.sample(list(cartas_truco.items()), 3)
    return(keys)


def selector_cartas():
    cartas_jugador = Jugador(cartas_truco)
    cartas_pc = Computadora(cartas_truco)

    for i in cartas_jugador:
        for j in range(len(cartas_pc)):
            if cartas_pc[j] == i:
                cartas_jugador = Jugador(cartas_truco)
        
            
#validador_cartas(cartas_jugador)

print(cartas_jugador)
print(cartas_pc)

def batalla_pc(carta):
    jugada_pc = carta[1]
    return jugada_pc

def batalla_jugador(carta):
    jugada_jugador = cartas_truco[str(j)]
    return jugada_jugador 
      
# 2. Inicio del juego con ciclo while
#while k != 0:
selector_cartas()

#Para implementar en el while
#Primera ronda 


#Selector cartas pc y valor 

#valor de la carta del pc
key_cartas_pc = list(cartas_pc[0])
print('El computador ha seleccionado la siguiente carta:', key_cartas_pc[0])
valor_batalla_pc = batalla_pc(list(cartas_pc[0]))

#valor de la carta del jugador
carta_jugador = list(cartas_jugador)
l = [w for w, v in cartas_jugador]
j = input("Ahora Elige tu carta: " + str(l) + " >>>    ")
valor_batalla_jugador = (batalla_jugador(j))

# Comparar valores del pc y del jugador 

if valor_batalla_pc > valor_batalla_jugador:
    cpu_score_batalla += 1
    print('El ganador de la batalla es la CPU')
elif valor_batalla_pc < valor_batalla_jugador:
    player_score_batalla += 1
    print('Fuiste el ganador de la batalla')
else:    
    cpu_score_batalla += 1
    player_score_batalla += 1
    print('Esta batalla quedo en empate')
    
print('puntaje pc',cpu_score_batalla)
print('puntaje player',player_score_batalla)
    

#Imprimir solo los keys de las cartas que le toco al jugador
# Out:
# Ingrese Nombre: fdafa
# FDAFA Empecemos!
# Ingrese la cantidad de rondas que quiere jugar, recuerde que las rondas deben ser numeros impares:3
# Vamos a jugar: 3 rondas
# []
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-134-dfe526eb34ca> in <module>
#      79
#      80 #valor de la carta del pc
# ---> 81 key_cartas_pc = list(cartas_pc[0])
#      82 print('El computador ha seleccionado la siguiente carta:', key_cartas_pc[0])
#      83 valor_batalla_pc = batalla_pc(list(cartas_pc[0]))
#
# IndexError: list index out of range
